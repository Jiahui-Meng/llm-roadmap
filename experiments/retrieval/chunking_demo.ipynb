# %% [markdown]
# # Chunking Demo

# %% [markdown]
# ## Goal
#
# Compare fixed-size chunks, overlap chunks, and paragraph chunks on the same source article.

# %% [markdown]
# ## Evaluation lens
#
# Look at retrieval granularity, citation readability, and context fragmentation.

# %% [markdown]
# ## Next step
#
# Use the chunking choice later in the RAG ablation report.
