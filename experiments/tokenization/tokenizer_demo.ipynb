# %% [markdown]
# # Tokenizer Demo

# %% [markdown]
# ## Goal
#
# Compare simple tokenization examples across English and Chinese and note why subword tokenization matters.

# %% [markdown]
# ## Examples
#
# `Transformers are powerful` vs `大型语言模型很强` and how tokens can split differently.

# %% [markdown]
# ## What to record
#
# Track token count, unknown token behavior, and implications for context length.
